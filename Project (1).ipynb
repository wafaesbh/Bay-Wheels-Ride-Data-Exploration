# %%
df = spark.read.csv("/FileStore/tables/201806_fordgobike_tripdata.csv", header="true", inferSchema="true")
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a view or table

temp_table_name = "201806_fordgobike_tripdata_csv"
df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df.select("start_time").summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>start_time</th></tr></thead><tbody><tr><td>count</td><td>195968</td></tr><tr><td>mean</td><td>null</td></tr><tr><td>stddev</td><td>null</td></tr><tr><td>min</td><td>2018-06-01 00:02:28.3230</td></tr><tr><td>25%</td><td>null</td></tr><tr><td>50%</td><td>null</td></tr><tr><td>75%</td><td>null</td></tr><tr><td>max</td><td>2018-06-30 23:58:48.2930</td></tr></tbody></table></div>

# %%
display(df.select("end_time").summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>end_time</th></tr></thead><tbody><tr><td>count</td><td>195968</td></tr><tr><td>mean</td><td>null</td></tr><tr><td>stddev</td><td>null</td></tr><tr><td>min</td><td>2018-06-01 00:07:21.1330</td></tr><tr><td>25%</td><td>null</td></tr><tr><td>50%</td><td>null</td></tr><tr><td>75%</td><td>null</td></tr><tr><td>max</td><td>2018-07-01 15:57:33.3160</td></tr></tbody></table></div>

# %%
# %sql
/* Query the created temp table in a SQL cell */

select * from `201806_fordgobike_tripdata_csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
#Durée du trajet du système Bay Wheels en secondes

select duration_sec from `201806_fordgobike_tripdata_csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
# durée max d un trajet en secondes

select max(duration_sec) from `201806_fordgobike_tripdata_csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>max(duration_sec)</th></tr></thead><tbody><tr><td>85278</td></tr></tbody></table></div>

# %%
display(df.sort("duration_sec") \
    .groupBy("start_station_name")\
    .count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df.sort("duration_sec") \
    .groupBy("end_station_name")\
    .count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df.select("user_type"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
